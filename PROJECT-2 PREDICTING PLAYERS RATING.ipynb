# %%
import sqlite3

# %%
conn= sqlite3.connect('D:\Datascience_Assignments\Project2\database.sqlite')

# %%
import pandas as pd

# %%
df = pd.read_sql_query("SELECT * FROM Player_Attributes", conn)

# %%
df.shape
# Out:
# (183978, 42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# Data columns (total 42 columns):
# id                     183978 non-null int64
# player_fifa_api_id     183978 non-null int64
# player_api_id          183978 non-null int64
# date                   183978 non-null object
# overall_rating         183142 non-null float64
# potential              183142 non-null float64
# preferred_foot         183142 non-null object
# attacking_work_rate    180748 non-null object
# defensive_work_rate    183142 non-null object
# crossing               183142 non-null float64
# finishing              183142 non-null float64
# heading_accuracy       183142 non-null float64
# short_passing          183142 non-null float64
# volleys                181265 non-null float64
# dribbling              183142 non-null float64
# curve                  181265 non-null float64
# free_kick_accuracy     183142 non-null float64
# long_passing           183142 non-null float64
# ...

# %%
df['overall_rating'].count()
# Out:
# 183142

# %%
df['overall_rating'].nunique()
# Out:
# 61

# %%
cat_columns=df.columns[df.dtypes=='object']

# %%
cat_columns
# Out:
# Index(['date', 'preferred_foot', 'attacking_work_rate', 'defensive_work_rate'], dtype='object')

# %%
cat_columns=cat_columns[1:]

# %%
cat_columns
# Out:
# Index(['preferred_foot', 'attacking_work_rate', 'defensive_work_rate'], dtype='object')

# %%
df[cat_columns]
# Out:
#        preferred_foot attacking_work_rate defensive_work_rate
# 0               right              medium              medium
# 1               right              medium              medium
# 2               right              medium              medium
# 3               right              medium              medium
# 4               right              medium              medium
# 5                left                high              medium
# 6                left                high              medium
# 7                left                high              medium
# 8                left                high              medium
# 9                left                high              medium
# 10               left                high              medium
# 11               left                high              medium
# 12               left              medium              medium
# 13               left              medium              medium
# ...

# %%
import numpy as np

# %%
df.columns[df.dtypes==np.number]
# Out:
# Index(['overall_rating', 'potential', 'crossing', 'finishing',
#        'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve',
#        'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration',
#        'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power',
#        'jumping', 'stamina', 'strength', 'long_shots', 'aggression',
#        'interceptions', 'positioning', 'vision', 'penalties', 'marking',
#        'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling',
#        'gk_kicking', 'gk_positioning', 'gk_reflexes'],
#       dtype='object')

# %%
df_num=df[df.columns[df.dtypes==np.number]]

# %%
df_num
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# 5                 74.0       76.0      80.0       53.0              58.0
# 6                 74.0       76.0      80.0       53.0              58.0
# 7                 73.0       75.0      79.0       52.0              57.0
# 8                 73.0       75.0      79.0       51.0              57.0
# 9                 73.0       75.0      79.0       51.0              57.0
# 10                73.0       77.0      79.0       51.0              57.0
# 11                74.0       78.0      79.0       51.0              57.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# Data columns (total 42 columns):
# id                     183978 non-null int64
# player_fifa_api_id     183978 non-null int64
# player_api_id          183978 non-null int64
# date                   183978 non-null object
# overall_rating         183142 non-null float64
# potential              183142 non-null float64
# preferred_foot         183142 non-null object
# attacking_work_rate    180748 non-null object
# defensive_work_rate    183142 non-null object
# crossing               183142 non-null float64
# finishing              183142 non-null float64
# heading_accuracy       183142 non-null float64
# short_passing          183142 non-null float64
# volleys                181265 non-null float64
# dribbling              183142 non-null float64
# curve                  181265 non-null float64
# free_kick_accuracy     183142 non-null float64
# long_passing           183142 non-null float64
# ...

# %%
imputer=Imputer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-3a9c8a246af8> in <module>()
# ----> 1 imputer=Imputer()
#
# NameError: name 'Imputer' is not defined

# %%
from sklearn.preprocessing import Imputer

# %%
imputer=Imputer()

# %%
imputer.fit_transform(df_num)
# Out:
# array([[67., 71., 49., ..., 10.,  8.,  8.],
#        [67., 71., 49., ..., 10.,  8.,  8.],
#        [62., 66., 49., ..., 10.,  8.,  8.],
#        ...,
#        [77., 80., 74., ..., 73., 20., 20.],
#        [78., 81., 74., ..., 73., 20., 20.],
#        [80., 81., 74., ..., 78.,  7., 15.]])

# %%
df_num_array=imputer.fit_transform(df_num)

# %%
df-num_array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-53c50fa6e922> in <module>()
# ----> 1 df-num_array
#
# NameError: name 'num_array' is not defined

# %%
df_num_array
# Out:
# array([[67., 71., 49., ..., 10.,  8.,  8.],
#        [67., 71., 49., ..., 10.,  8.,  8.],
#        [62., 66., 49., ..., 10.,  8.,  8.],
#        ...,
#        [77., 80., 74., ..., 73., 20., 20.],
#        [78., 81., 74., ..., 73., 20., 20.],
#        [80., 81., 74., ..., 78.,  7., 15.]])

# %%
pd.DataFrame[df_num_array,columns=df_num.columns]
# Out:
#   File "<ipython-input-27-3231fa76cb9d>", line 1
#     pd.DataFrame[df_num_array,columns=df_num.columns]
#                                      ^
# SyntaxError: invalid syntax

# %%
pd.DataFrame(df_num_array,columns=df_num.columns)
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# 5                 74.0       76.0      80.0       53.0              58.0
# 6                 74.0       76.0      80.0       53.0              58.0
# 7                 73.0       75.0      79.0       52.0              57.0
# 8                 73.0       75.0      79.0       51.0              57.0
# 9                 73.0       75.0      79.0       51.0              57.0
# 10                73.0       77.0      79.0       51.0              57.0
# 11                74.0       78.0      79.0       51.0              57.0
# ...

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# Data columns (total 35 columns):
# overall_rating        183142 non-null float64
# potential             183142 non-null float64
# crossing              183142 non-null float64
# finishing             183142 non-null float64
# heading_accuracy      183142 non-null float64
# short_passing         183142 non-null float64
# volleys               181265 non-null float64
# dribbling             183142 non-null float64
# curve                 181265 non-null float64
# free_kick_accuracy    183142 non-null float64
# long_passing          183142 non-null float64
# ball_control          183142 non-null float64
# acceleration          183142 non-null float64
# sprint_speed          183142 non-null float64
# agility               181265 non-null float64
# reactions             183142 non-null float64
# balance               181265 non-null float64
# shot_power            183142 non-null float64
# ...

# %%
features=df_num.columns[1:]

# %%
target=df_num.columns[0]

# %%
x=df_num[features]

# %%
y=df_num[target]

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
target
# Out:
# 'overall_rating'

# %%
reg.score(x,y)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-39-18fb72f08cb2> in <module>()
# ----> 1 reg.score(x,y)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     384
#     385         from .metrics import r2_score
# --> 386         return r2_score(y, self.predict(X), sample_weight=sample_weight,
#     387                         multioutput='variance_weighted')
#     388
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     254             Returns predicted values.
#     255         """
# --> 256         return self._decision_function(X)
#     257
#     258     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     235
#     236     def _decision_function(self, X):
# ...

# %%
df[df_nums]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-c4de93816c45> in <module>()
# ----> 1 df[df_nums]
#
# NameError: name 'df_nums' is not defined

# %%
df[df_num]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-af86bd42c8c7> in <module>()
# ----> 1 df[df_num]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
# -> 2681             return self._getitem_frame(key)
#    2682         elif is_mi_columns:
#    2683             return self._getitem_multilevel(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_frame(self, key)
#    2762     def _getitem_frame(self, key):
#    2763         if key.values.size and not is_bool_dtype(key.values):
# -> 2764             raise ValueError('Must pass DataFrame with boolean values only')
#    2765         return self.where(key)
#    2766
#
# ValueError: Must pass DataFrame with boolean values only

# %%
df_num
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# 5                 74.0       76.0      80.0       53.0              58.0
# 6                 74.0       76.0      80.0       53.0              58.0
# 7                 73.0       75.0      79.0       52.0              57.0
# 8                 73.0       75.0      79.0       51.0              57.0
# 9                 73.0       75.0      79.0       51.0              57.0
# 10                73.0       77.0      79.0       51.0              57.0
# 11                74.0       78.0      79.0       51.0              57.0
# ...

# %%
reg.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-b8797431b3c6> in <module>()
# ----> 1 reg.fit(x,y)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
X=df_num[df_num.columns[1:]]

# %%
y=df_num[df_num.columns[0]]

# %%
reg.fit(X , y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-3c5e1f7502ef> in <module>()
# ----> 1 reg.fit(X , y)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
pd.DataFrame(df_num_array,columns=df_num.columns)
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# 5                 74.0       76.0      80.0       53.0              58.0
# 6                 74.0       76.0      80.0       53.0              58.0
# 7                 73.0       75.0      79.0       52.0              57.0
# 8                 73.0       75.0      79.0       51.0              57.0
# 9                 73.0       75.0      79.0       51.0              57.0
# 10                73.0       77.0      79.0       51.0              57.0
# 11                74.0       78.0      79.0       51.0              57.0
# ...

# %%
df_num=pd.DataFrame(df_num_array,columns=df_num.columns)

# %%
df_num
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# 5                 74.0       76.0      80.0       53.0              58.0
# 6                 74.0       76.0      80.0       53.0              58.0
# 7                 73.0       75.0      79.0       52.0              57.0
# 8                 73.0       75.0      79.0       51.0              57.0
# 9                 73.0       75.0      79.0       51.0              57.0
# 10                73.0       77.0      79.0       51.0              57.0
# 11                74.0       78.0      79.0       51.0              57.0
# ...

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# Data columns (total 35 columns):
# overall_rating        183978 non-null float64
# potential             183978 non-null float64
# crossing              183978 non-null float64
# finishing             183978 non-null float64
# heading_accuracy      183978 non-null float64
# short_passing         183978 non-null float64
# volleys               183978 non-null float64
# dribbling             183978 non-null float64
# curve                 183978 non-null float64
# free_kick_accuracy    183978 non-null float64
# long_passing          183978 non-null float64
# ball_control          183978 non-null float64
# acceleration          183978 non-null float64
# sprint_speed          183978 non-null float64
# agility               183978 non-null float64
# reactions             183978 non-null float64
# balance               183978 non-null float64
# shot_power            183978 non-null float64
# ...

# %%
 features=df_num.columns[1:]

# %%
target=df_num.columns[0]

# %%
X=df_num[features]

# %%
y=df_num[target]

# %%
X
# Out:
#         potential  crossing  finishing  heading_accuracy  short_passing  \
# 0            71.0      49.0       44.0              71.0           61.0
# 1            71.0      49.0       44.0              71.0           61.0
# 2            66.0      49.0       44.0              71.0           61.0
# 3            65.0      48.0       43.0              70.0           60.0
# 4            65.0      48.0       43.0              70.0           60.0
# 5            76.0      80.0       53.0              58.0           71.0
# 6            76.0      80.0       53.0              58.0           71.0
# 7            75.0      79.0       52.0              57.0           70.0
# 8            75.0      79.0       51.0              57.0           70.0
# 9            75.0      79.0       51.0              57.0           70.0
# 10           77.0      79.0       51.0              57.0           70.0
# 11           78.0      79.0       51.0              57.0           70.0
# ...

# %%
y
# Out:
# 0         67.0
# 1         67.0
# 2         62.0
# 3         61.0
# 4         61.0
# 5         74.0
# 6         74.0
# 7         73.0
# 8         73.0
# 9         73.0
# 10        73.0
# 11        74.0
# 12        73.0
# 13        71.0
# 14        71.0
# 15        71.0
# 16        70.0
# 17        70.0
# 18        70.0
# 19        70.0
# 20        70.0
# 21        70.0
# 22        69.0
# 23        69.0
# 24        69.0
# 25        69.0
# 26        69.0
# 27        69.0
# 28        69.0
# 29        68.0
#           ...
# 183948    68.0
# 183949    68.0
# 183950    68.0
# 183951    67.0
# 183952    67.0
# 183953    68.0
# 183954    68.0
# 183955    68.0
# 183956    68.0
# 183957    67.0
# 183958    67.0
# 183959    67.0
# 183960    67.0
# 183961    67.0
# 183962    67.0
# 183963    70.0
# 183964    70.0
# 183965    72.0
# 183966    75.0
# 183967    78.0
# 183968    78.0
# 183969    81.0
# 183970    81.0
# 183971    81.0
# 183972    83.0
# 183973    83.0
# 183974    78.0
# ...

# %%
reg=LinearRegression()

# %%
reg.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.Score(X,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-8a6e50766831> in <module>()
# ----> 1 reg.Score(X,y)
#
# AttributeError: 'LinearRegression' object has no attribute 'Score'

# %%
reg.score(X,y)
# Out:
# 0.8413480516699354

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree=DecisionTreeRegressor()

# %%
tree.fit(X,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
tree.score(X,y)
# Out:
# 0.999200268968774
